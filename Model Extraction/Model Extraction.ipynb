# %%
bert_model_path = "..\\custom_models\\bert_model"
extraction_dataset_path = "..\\custom_datasets\\extraction_dataset"
extraction_model_path = "..\\custom_models\\extracted_bert_model"
training_log_path = "extraction_training_log.txt"

# %%
import os
import sys
sys.path.append(os.path.realpath("../"))

# %%
import gc
import torch
import ModelParamFunctionsModule as mpfm
from datasets import load_from_disk
from torch.optim import AdamW
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
from transformers import BertForPreTraining, DefaultDataCollator, get_scheduler

# %%
extraction_dataset = load_from_disk(extraction_dataset_path)

# %%
extraction_data_loader = DataLoader(extraction_dataset['train'], batch_size=16, shuffle=True, collate_fn=DefaultDataCollator(), pin_memory=True, pin_memory_device="cuda:0")

# %%
device = torch.device("cuda") if torch.cuda.is_available else torch.device("cpu")

# %%
bert_model = BertForPreTraining.from_pretrained(bert_model_path)
bert_model.to(device)
# Out:
# BertForPreTraining(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (cls): BertPreTrainingHeads(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (transform_act_fn): GELUActivation()
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=28996, bias=True)
#     )
#     (seq_relationship): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
bert_model.apply(mpfm.reinitialize_weights)
mpfm.print_params_details(bert_model)
# Out:
# bert.embeddings.word_embeddings.weight: mean=0.0000; std=0.0200
# bert.embeddings.position_embeddings.weight: mean=-0.0001; std=0.0200
# bert.embeddings.token_type_embeddings.weight: mean=0.0003; std=0.0196
# bert.embeddings.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.embeddings.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.attention.self.query.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.0.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.0.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.attention.self.value.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.0.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.attention.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.0.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.0.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.intermediate.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.0.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.0.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.0.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.0.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.attention.self.query.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.1.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.1.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.attention.self.value.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.1.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.attention.output.dense.weight: mean=0.0001; std=0.0200
# bert.encoder.layer.1.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.1.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.1.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.1.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.1.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.1.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.attention.self.query.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.2.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.2.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.attention.self.value.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.2.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.attention.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.2.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.2.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.2.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.2.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.2.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.2.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.attention.self.query.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.3.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.attention.self.key.weight: mean=0.0001; std=0.0200
# bert.encoder.layer.3.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.attention.self.value.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.3.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.attention.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.3.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.3.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.3.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.3.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.3.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.3.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.attention.self.query.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.4.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.4.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.attention.self.value.weight: mean=0.0001; std=0.0200
# bert.encoder.layer.4.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.attention.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.4.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.4.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.intermediate.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.4.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.4.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.4.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.4.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.attention.self.query.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.5.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.5.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.attention.self.value.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.5.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.attention.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.5.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.5.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.5.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.5.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.5.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.5.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.attention.self.query.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.6.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.6.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.attention.self.value.weight: mean=0.0001; std=0.0200
# bert.encoder.layer.6.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.attention.output.dense.weight: mean=-0.0001; std=0.0200
# bert.encoder.layer.6.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.6.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.intermediate.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.6.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.6.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.6.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.6.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.attention.self.query.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.7.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.7.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.attention.self.value.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.7.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.attention.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.7.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.7.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.7.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.7.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.7.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.7.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.attention.self.query.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.8.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.8.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.attention.self.value.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.8.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.attention.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.8.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.8.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.8.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.8.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.8.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.8.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.attention.self.query.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.9.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.attention.self.key.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.9.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.attention.self.value.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.9.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.attention.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.9.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.9.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.9.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.9.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.9.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.9.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.attention.self.query.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.10.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.attention.self.key.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.10.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.attention.self.value.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.10.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.attention.output.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.10.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.10.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.intermediate.dense.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.10.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.10.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.10.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.10.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.attention.self.query.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.11.attention.self.query.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.attention.self.key.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.11.attention.self.key.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.attention.self.value.weight: mean=-0.0000; std=0.0200
# bert.encoder.layer.11.attention.self.value.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.attention.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.11.attention.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.attention.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.11.attention.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.intermediate.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.11.intermediate.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.output.dense.weight: mean=0.0000; std=0.0200
# bert.encoder.layer.11.output.dense.bias: mean=0.0000; std=0.0000
# bert.encoder.layer.11.output.LayerNorm.weight: mean=1.0000; std=0.0000
# bert.encoder.layer.11.output.LayerNorm.bias: mean=0.0000; std=0.0000
# bert.pooler.dense.weight: mean=0.0000; std=0.0200
# bert.pooler.dense.bias: mean=0.0000; std=0.0000
# cls.predictions.bias: mean=0.0000; std=0.0000
# cls.predictions.transform.dense.weight: mean=0.0000; std=0.0200
# cls.predictions.transform.dense.bias: mean=0.0000; std=0.0000
# cls.predictions.transform.LayerNorm.weight: mean=1.0000; std=0.0000
# cls.predictions.transform.LayerNorm.bias: mean=0.0000; std=0.0000
# cls.seq_relationship.weight: mean=-0.0001; std=0.0199
# cls.seq_relationship.bias: mean=0.0000; std=0.0000

# %%
num_training_steps = len(extraction_data_loader)
adam_optimizer = AdamW(bert_model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=0.01)
lr_scheduler = get_scheduler("linear", adam_optimizer, num_warmup_steps=1000, num_training_steps=num_training_steps)

# %%
def treinar(training_progress_bar, stopping_point = 0):
    current_training_step = 0
    current_training_substep = 0
    training_substep_marker = 2000
    training_log = open(training_log_path, mode="a", encoding="utf-8")
    bert_model.train()
    while stopping_point == 0 or current_training_step < stopping_point:
        loss = 0
        for batch in extraction_data_loader:
            del(batch['idx'])
            batch = {k: v.to(device) for k, v in batch.items()}
            outputs = bert_model(**batch)
            loss = outputs.loss
            loss.backward()

            adam_optimizer.step()
            lr_scheduler.step()
            adam_optimizer.zero_grad()
            training_progress_bar.update(1)

            gc.collect()
            torch.cuda.empty_cache()
            
            current_training_step += 1
            current_training_substep += 1
            if(current_training_substep >= training_substep_marker):
                training_log.write(str(current_training_step) + ": " + str(loss) + "\n")
                current_training_substep = 0
            if(stopping_point > 0 and current_training_step >= stopping_point):
                break
        print(current_training_step, ": ", loss)
        if(stopping_point == 0):
            break
    training_log.close()

# %%
treinar(tqdm(range(num_training_steps)))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 treinar(tqdm(range(num_training_steps)))
#
# Cell In[10], line 12, in treinar(training_progress_bar, stopping_point)
#      10 del(batch['idx'])
#      11 batch = {k: v.to(device) for k, v in batch.items()}
# ---> 12 outputs = bert_model(**batch)
#      13 loss = outputs.loss
#      14 loss.backward()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bert\modeling_bert.py:1129, in BertForPreTraining.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, next_sentence_label, output_attentions, output_hidden_states, return_dict)
#    1116 outputs = self.bert(
#    1117     input_ids,
#    1118     attention_mask=attention_mask,
#    (...)
#    1125     return_dict=return_dict,
#    1126 )
#    1128 sequence_output, pooled_output = outputs[:2]
# -> 1129 prediction_scores, seq_relationship_score = self.cls(sequence_output, pooled_output)
#    1131 total_loss = None
#    1132 if labels is not None and next_sentence_label is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bert\modeling_bert.py:728, in BertPreTrainingHeads.forward(self, sequence_output, pooled_output)
#     727 def forward(self, sequence_output, pooled_output):
# --> 728     prediction_scores = self.predictions(sequence_output)
#     729     seq_relationship_score = self.seq_relationship(pooled_output)
#     730     return prediction_scores, seq_relationship_score
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bert\modeling_bert.py:697, in BertLMPredictionHead.forward(self, hidden_states)
#     695 def forward(self, hidden_states):
#     696     hidden_states = self.transform(hidden_states)
# --> 697     hidden_states = self.decoder(hidden_states)
#     698     return hidden_states
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 908.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 10.24 GiB is allocated by PyTorch, and 37.90 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
mpfm.print_params_details(bert_model)
# Out:
# bert.embeddings.word_embeddings.weight: mean=-0.0000; std=0.0331
# bert.embeddings.position_embeddings.weight: mean=0.0000; std=0.0195
# bert.embeddings.token_type_embeddings.weight: mean=-0.0002; std=0.0155
# bert.embeddings.LayerNorm.weight: mean=0.8229; std=0.0844
# bert.embeddings.LayerNorm.bias: mean=0.0001; std=0.0272
# bert.encoder.layer.0.attention.self.query.weight: mean=-0.0000; std=0.0299
# bert.encoder.layer.0.attention.self.query.bias: mean=-0.0020; std=0.0303
# bert.encoder.layer.0.attention.self.key.weight: mean=-0.0000; std=0.0297
# bert.encoder.layer.0.attention.self.key.bias: mean=-0.0003; std=0.0081
# bert.encoder.layer.0.attention.self.value.weight: mean=-0.0000; std=0.0226
# bert.encoder.layer.0.attention.self.value.bias: mean=-0.0017; std=0.0290
# bert.encoder.layer.0.attention.output.dense.weight: mean=-0.0000; std=0.0224
# bert.encoder.layer.0.attention.output.dense.bias: mean=-0.0019; std=0.0438
# bert.encoder.layer.0.attention.output.LayerNorm.weight: mean=0.8721; std=0.0613
# bert.encoder.layer.0.attention.output.LayerNorm.bias: mean=-0.0031; std=0.0990
# bert.encoder.layer.0.intermediate.dense.weight: mean=-0.0000; std=0.0319
# bert.encoder.layer.0.intermediate.dense.bias: mean=-0.0461; std=0.0192
# bert.encoder.layer.0.output.dense.weight: mean=-0.0001; std=0.0275
# bert.encoder.layer.0.output.dense.bias: mean=-0.0004; std=0.0123
# bert.encoder.layer.0.output.LayerNorm.weight: mean=0.8040; std=0.0615
# bert.encoder.layer.0.output.LayerNorm.bias: mean=-0.0007; std=0.0392
# bert.encoder.layer.1.attention.self.query.weight: mean=-0.0000; std=0.0277
# bert.encoder.layer.1.attention.self.query.bias: mean=0.0003; std=0.0109
# bert.encoder.layer.1.attention.self.key.weight: mean=0.0000; std=0.0280
# bert.encoder.layer.1.attention.self.key.bias: mean=-0.0005; std=0.0090
# bert.encoder.layer.1.attention.self.value.weight: mean=-0.0000; std=0.0212
# bert.encoder.layer.1.attention.self.value.bias: mean=0.0002; std=0.0111
# bert.encoder.layer.1.attention.output.dense.weight: mean=0.0000; std=0.0201
# bert.encoder.layer.1.attention.output.dense.bias: mean=-0.0019; std=0.0468
# bert.encoder.layer.1.attention.output.LayerNorm.weight: mean=0.8775; std=0.0494
# bert.encoder.layer.1.attention.output.LayerNorm.bias: mean=-0.0036; std=0.0853
# bert.encoder.layer.1.intermediate.dense.weight: mean=-0.0000; std=0.0318
# bert.encoder.layer.1.intermediate.dense.bias: mean=-0.0416; std=0.0175
# bert.encoder.layer.1.output.dense.weight: mean=0.0000; std=0.0274
# bert.encoder.layer.1.output.dense.bias: mean=-0.0004; std=0.0117
# bert.encoder.layer.1.output.LayerNorm.weight: mean=0.8112; std=0.0543
# bert.encoder.layer.1.output.LayerNorm.bias: mean=-0.0009; std=0.0418
# bert.encoder.layer.2.attention.self.query.weight: mean=-0.0000; std=0.0279
# bert.encoder.layer.2.attention.self.query.bias: mean=-0.0002; std=0.0110
# bert.encoder.layer.2.attention.self.key.weight: mean=0.0000; std=0.0284
# bert.encoder.layer.2.attention.self.key.bias: mean=0.0003; std=0.0075
# bert.encoder.layer.2.attention.self.value.weight: mean=-0.0000; std=0.0214
# bert.encoder.layer.2.attention.self.value.bias: mean=0.0004; std=0.0108
# bert.encoder.layer.2.attention.output.dense.weight: mean=-0.0000; std=0.0203
# bert.encoder.layer.2.attention.output.dense.bias: mean=-0.0022; std=0.0457
# bert.encoder.layer.2.attention.output.LayerNorm.weight: mean=0.8794; std=0.0527
# bert.encoder.layer.2.attention.output.LayerNorm.bias: mean=-0.0050; std=0.0811
# bert.encoder.layer.2.intermediate.dense.weight: mean=0.0001; std=0.0318
# bert.encoder.layer.2.intermediate.dense.bias: mean=-0.0437; std=0.0197
# bert.encoder.layer.2.output.dense.weight: mean=0.0001; std=0.0272
# bert.encoder.layer.2.output.dense.bias: mean=-0.0005; std=0.0110
# bert.encoder.layer.2.output.LayerNorm.weight: mean=0.7988; std=0.0552
# bert.encoder.layer.2.output.LayerNorm.bias: mean=-0.0006; std=0.0429
# bert.encoder.layer.3.attention.self.query.weight: mean=0.0000; std=0.0264
# bert.encoder.layer.3.attention.self.query.bias: mean=-0.0010; std=0.0132
# bert.encoder.layer.3.attention.self.key.weight: mean=0.0000; std=0.0272
# bert.encoder.layer.3.attention.self.key.bias: mean=0.0003; std=0.0041
# bert.encoder.layer.3.attention.self.value.weight: mean=-0.0000; std=0.0216
# bert.encoder.layer.3.attention.self.value.bias: mean=-0.0006; std=0.0093
# bert.encoder.layer.3.attention.output.dense.weight: mean=0.0000; std=0.0202
# bert.encoder.layer.3.attention.output.dense.bias: mean=-0.0027; std=0.0403
# bert.encoder.layer.3.attention.output.LayerNorm.weight: mean=0.8823; std=0.0470
# bert.encoder.layer.3.attention.output.LayerNorm.bias: mean=-0.0047; std=0.0757
# bert.encoder.layer.3.intermediate.dense.weight: mean=0.0002; std=0.0316
# bert.encoder.layer.3.intermediate.dense.bias: mean=-0.0406; std=0.0216
# bert.encoder.layer.3.output.dense.weight: mean=0.0000; std=0.0273
# bert.encoder.layer.3.output.dense.bias: mean=-0.0003; std=0.0128
# bert.encoder.layer.3.output.LayerNorm.weight: mean=0.8072; std=0.0541
# bert.encoder.layer.3.output.LayerNorm.bias: mean=-0.0000; std=0.0398
# bert.encoder.layer.4.attention.self.query.weight: mean=0.0000; std=0.0269
# bert.encoder.layer.4.attention.self.query.bias: mean=0.0006; std=0.0131
# bert.encoder.layer.4.attention.self.key.weight: mean=0.0000; std=0.0277
# bert.encoder.layer.4.attention.self.key.bias: mean=-0.0002; std=0.0053
# bert.encoder.layer.4.attention.self.value.weight: mean=-0.0000; std=0.0219
# bert.encoder.layer.4.attention.self.value.bias: mean=0.0002; std=0.0105
# bert.encoder.layer.4.attention.output.dense.weight: mean=-0.0000; std=0.0208
# bert.encoder.layer.4.attention.output.dense.bias: mean=-0.0024; std=0.0400
# bert.encoder.layer.4.attention.output.LayerNorm.weight: mean=0.8847; std=0.0503
# bert.encoder.layer.4.attention.output.LayerNorm.bias: mean=-0.0053; std=0.0758
# bert.encoder.layer.4.intermediate.dense.weight: mean=0.0003; std=0.0317
# bert.encoder.layer.4.intermediate.dense.bias: mean=-0.0401; std=0.0217
# bert.encoder.layer.4.output.dense.weight: mean=0.0000; std=0.0275
# bert.encoder.layer.4.output.dense.bias: mean=0.0000; std=0.0118
# bert.encoder.layer.4.output.LayerNorm.weight: mean=0.8084; std=0.0534
# bert.encoder.layer.4.output.LayerNorm.bias: mean=0.0011; std=0.0368
# bert.encoder.layer.5.attention.self.query.weight: mean=-0.0000; std=0.0260
# bert.encoder.layer.5.attention.self.query.bias: mean=-0.0007; std=0.0139
# bert.encoder.layer.5.attention.self.key.weight: mean=-0.0000; std=0.0269
# bert.encoder.layer.5.attention.self.key.bias: mean=0.0000; std=0.0029
# bert.encoder.layer.5.attention.self.value.weight: mean=-0.0000; std=0.0215
# bert.encoder.layer.5.attention.self.value.bias: mean=0.0001; std=0.0098
# bert.encoder.layer.5.attention.output.dense.weight: mean=0.0000; std=0.0202
# bert.encoder.layer.5.attention.output.dense.bias: mean=-0.0021; std=0.0377
# bert.encoder.layer.5.attention.output.LayerNorm.weight: mean=0.8886; std=0.0486
# bert.encoder.layer.5.attention.output.LayerNorm.bias: mean=-0.0029; std=0.0740
# bert.encoder.layer.5.intermediate.dense.weight: mean=0.0002; std=0.0319
# bert.encoder.layer.5.intermediate.dense.bias: mean=-0.0390; std=0.0196
# bert.encoder.layer.5.output.dense.weight: mean=-0.0000; std=0.0277
# bert.encoder.layer.5.output.dense.bias: mean=0.0004; std=0.0125
# bert.encoder.layer.5.output.LayerNorm.weight: mean=0.8156; std=0.0534
# bert.encoder.layer.5.output.LayerNorm.bias: mean=0.0018; std=0.0342
# bert.encoder.layer.6.attention.self.query.weight: mean=-0.0000; std=0.0280
# bert.encoder.layer.6.attention.self.query.bias: mean=0.0007; std=0.0152
# bert.encoder.layer.6.attention.self.key.weight: mean=-0.0000; std=0.0284
# bert.encoder.layer.6.attention.self.key.bias: mean=0.0002; std=0.0041
# bert.encoder.layer.6.attention.self.value.weight: mean=-0.0000; std=0.0227
# bert.encoder.layer.6.attention.self.value.bias: mean=0.0001; std=0.0129
# bert.encoder.layer.6.attention.output.dense.weight: mean=-0.0000; std=0.0219
# bert.encoder.layer.6.attention.output.dense.bias: mean=-0.0017; std=0.0376
# bert.encoder.layer.6.attention.output.LayerNorm.weight: mean=0.8856; std=0.0514
# bert.encoder.layer.6.attention.output.LayerNorm.bias: mean=-0.0036; std=0.0754
# bert.encoder.layer.6.intermediate.dense.weight: mean=0.0003; std=0.0317
# bert.encoder.layer.6.intermediate.dense.bias: mean=-0.0380; std=0.0170
# bert.encoder.layer.6.output.dense.weight: mean=-0.0000; std=0.0277
# bert.encoder.layer.6.output.dense.bias: mean=0.0002; std=0.0132
# bert.encoder.layer.6.output.LayerNorm.weight: mean=0.8055; std=0.0529
# bert.encoder.layer.6.output.LayerNorm.bias: mean=0.0015; std=0.0363
# bert.encoder.layer.7.attention.self.query.weight: mean=0.0000; std=0.0268
# bert.encoder.layer.7.attention.self.query.bias: mean=-0.0003; std=0.0187
# bert.encoder.layer.7.attention.self.key.weight: mean=-0.0000; std=0.0274
# bert.encoder.layer.7.attention.self.key.bias: mean=-0.0003; std=0.0037
# bert.encoder.layer.7.attention.self.value.weight: mean=0.0000; std=0.0229
# bert.encoder.layer.7.attention.self.value.bias: mean=0.0001; std=0.0124
# bert.encoder.layer.7.attention.output.dense.weight: mean=0.0000; std=0.0220
# bert.encoder.layer.7.attention.output.dense.bias: mean=-0.0011; std=0.0393
# bert.encoder.layer.7.attention.output.LayerNorm.weight: mean=0.8859; std=0.0494
# bert.encoder.layer.7.attention.output.LayerNorm.bias: mean=-0.0030; std=0.0756
# bert.encoder.layer.7.intermediate.dense.weight: mean=0.0002; std=0.0317
# bert.encoder.layer.7.intermediate.dense.bias: mean=-0.0372; std=0.0156
# bert.encoder.layer.7.output.dense.weight: mean=-0.0000; std=0.0279
# bert.encoder.layer.7.output.dense.bias: mean=0.0002; std=0.0129
# bert.encoder.layer.7.output.LayerNorm.weight: mean=0.8123; std=0.0536
# bert.encoder.layer.7.output.LayerNorm.bias: mean=0.0014; std=0.0299
# bert.encoder.layer.8.attention.self.query.weight: mean=-0.0000; std=0.0283
# bert.encoder.layer.8.attention.self.query.bias: mean=0.0004; std=0.0200
# bert.encoder.layer.8.attention.self.key.weight: mean=0.0000; std=0.0287
# bert.encoder.layer.8.attention.self.key.bias: mean=0.0006; std=0.0068
# bert.encoder.layer.8.attention.self.value.weight: mean=-0.0000; std=0.0243
# bert.encoder.layer.8.attention.self.value.bias: mean=-0.0003; std=0.0215
# bert.encoder.layer.8.attention.output.dense.weight: mean=-0.0000; std=0.0236
# bert.encoder.layer.8.attention.output.dense.bias: mean=-0.0010; std=0.0346
# bert.encoder.layer.8.attention.output.LayerNorm.weight: mean=0.8808; std=0.0470
# bert.encoder.layer.8.attention.output.LayerNorm.bias: mean=-0.0021; std=0.0773
# bert.encoder.layer.8.intermediate.dense.weight: mean=0.0002; std=0.0313
# bert.encoder.layer.8.intermediate.dense.bias: mean=-0.0374; std=0.0136
# bert.encoder.layer.8.output.dense.weight: mean=-0.0000; std=0.0278
# bert.encoder.layer.8.output.dense.bias: mean=0.0000; std=0.0120
# bert.encoder.layer.8.output.LayerNorm.weight: mean=0.7896; std=0.0472
# bert.encoder.layer.8.output.LayerNorm.bias: mean=0.0017; std=0.0322
# bert.encoder.layer.9.attention.self.query.weight: mean=-0.0000; std=0.0265
# bert.encoder.layer.9.attention.self.query.bias: mean=0.0002; std=0.0227
# bert.encoder.layer.9.attention.self.key.weight: mean=-0.0000; std=0.0270
# bert.encoder.layer.9.attention.self.key.bias: mean=-0.0007; std=0.0157
# bert.encoder.layer.9.attention.self.value.weight: mean=0.0000; std=0.0244
# bert.encoder.layer.9.attention.self.value.bias: mean=0.0004; std=0.0168
# bert.encoder.layer.9.attention.output.dense.weight: mean=0.0000; std=0.0237
# bert.encoder.layer.9.attention.output.dense.bias: mean=-0.0003; std=0.0391
# bert.encoder.layer.9.attention.output.LayerNorm.weight: mean=0.8820; std=0.0405
# bert.encoder.layer.9.attention.output.LayerNorm.bias: mean=-0.0019; std=0.0702
# bert.encoder.layer.9.intermediate.dense.weight: mean=0.0002; std=0.0311
# bert.encoder.layer.9.intermediate.dense.bias: mean=-0.0346; std=0.0128
# bert.encoder.layer.9.output.dense.weight: mean=0.0000; std=0.0277
# bert.encoder.layer.9.output.dense.bias: mean=0.0000; std=0.0126
# bert.encoder.layer.9.output.LayerNorm.weight: mean=0.7646; std=0.0446
# bert.encoder.layer.9.output.LayerNorm.bias: mean=0.0010; std=0.0294
# bert.encoder.layer.10.attention.self.query.weight: mean=-0.0000; std=0.0257
# bert.encoder.layer.10.attention.self.query.bias: mean=0.0004; std=0.0226
# bert.encoder.layer.10.attention.self.key.weight: mean=0.0000; std=0.0261
# bert.encoder.layer.10.attention.self.key.bias: mean=-0.0004; std=0.0394
# bert.encoder.layer.10.attention.self.value.weight: mean=0.0000; std=0.0257
# bert.encoder.layer.10.attention.self.value.bias: mean=-0.0002; std=0.0121
# bert.encoder.layer.10.attention.output.dense.weight: mean=-0.0000; std=0.0251
# bert.encoder.layer.10.attention.output.dense.bias: mean=-0.0006; std=0.0353
# bert.encoder.layer.10.attention.output.LayerNorm.weight: mean=0.8834; std=0.0303
# bert.encoder.layer.10.attention.output.LayerNorm.bias: mean=-0.0007; std=0.0622
# bert.encoder.layer.10.intermediate.dense.weight: mean=0.0001; std=0.0309
# bert.encoder.layer.10.intermediate.dense.bias: mean=-0.0308; std=0.0125
# bert.encoder.layer.10.output.dense.weight: mean=0.0000; std=0.0277
# bert.encoder.layer.10.output.dense.bias: mean=0.0001; std=0.0119
# bert.encoder.layer.10.output.LayerNorm.weight: mean=0.7705; std=0.0369
# bert.encoder.layer.10.output.LayerNorm.bias: mean=0.0011; std=0.0293
# bert.encoder.layer.11.attention.self.query.weight: mean=0.0000; std=0.0256
# bert.encoder.layer.11.attention.self.query.bias: mean=0.0008; std=0.0159
# bert.encoder.layer.11.attention.self.key.weight: mean=-0.0000; std=0.0255
# bert.encoder.layer.11.attention.self.key.bias: mean=-0.0008; std=0.0434
# bert.encoder.layer.11.attention.self.value.weight: mean=0.0000; std=0.0240
# bert.encoder.layer.11.attention.self.value.bias: mean=0.0002; std=0.0131
# bert.encoder.layer.11.attention.output.dense.weight: mean=0.0000; std=0.0231
# bert.encoder.layer.11.attention.output.dense.bias: mean=-0.0004; std=0.0345
# bert.encoder.layer.11.attention.output.LayerNorm.weight: mean=0.8799; std=0.0233
# bert.encoder.layer.11.attention.output.LayerNorm.bias: mean=0.0003; std=0.0689
# bert.encoder.layer.11.intermediate.dense.weight: mean=0.0000; std=0.0306
# bert.encoder.layer.11.intermediate.dense.bias: mean=-0.0273; std=0.0144
# bert.encoder.layer.11.output.dense.weight: mean=0.0000; std=0.0271
# bert.encoder.layer.11.output.dense.bias: mean=-0.0001; std=0.0073
# bert.encoder.layer.11.output.LayerNorm.weight: mean=0.8304; std=0.0260
# bert.encoder.layer.11.output.LayerNorm.bias: mean=-0.0011; std=0.0186
# bert.pooler.dense.weight: mean=-0.0000; std=0.0266
# bert.pooler.dense.bias: mean=-0.0000; std=0.0206
# cls.predictions.bias: mean=-1.8092; std=1.7557
# cls.predictions.transform.dense.weight: mean=-0.0001; std=0.0326
# cls.predictions.transform.dense.bias: mean=0.0184; std=0.0332
# cls.predictions.transform.LayerNorm.weight: mean=1.5858; std=0.2284
# cls.predictions.transform.LayerNorm.bias: mean=0.0386; std=0.1027
# cls.seq_relationship.weight: mean=0.0005; std=0.0153
# cls.seq_relationship.bias: mean=-0.0000; std=0.0069

# %%
bert_model.save_pretrained(extraction_model_path)
