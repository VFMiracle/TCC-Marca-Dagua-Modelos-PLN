# %%
base_file_path = "open_web_text_lines_files\\open_web_text_dataset_file"
checkpoint = 'bert-base-cased'
dataset_folder_path = "..\\custom_datasets\\open_web_text_dataset"

# %%
from datasets import Dataset, DatasetDict
from tqdm.auto import tqdm
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# C:\Users\Vande\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
def open_web_text_dataset_gen(shards, dataset_name):
    progress_bar = tqdm(range(len(shards)))
    idx = 0
    for shard in shards:
        with open(shard, "r", encoding="utf-8") as file:
            for text in file:
                yield {"idx": idx, "text": tokenizer(text[0:-1], max_length = 512, truncation = True)['input_ids'][1:-1]}
                idx += 1
            progress_bar.update()

# %%
def build_open_web_text_dataset_dict():
    train_shards = [base_file_path + str(i) + ".txt" for i in range(84)]
    return DatasetDict({
        "train": Dataset.from_generator(open_web_text_dataset_gen, gen_kwargs={"shards": train_shards, "dataset_name": "train"})
    })

# %%
open_web_text_dataset_dict = build_open_web_text_dataset_dict()
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
#   0%|          | 0/84 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 open_web_text_dataset_dict = build_open_web_text_dataset_dict()
#
# Cell In[6], line 4, in build_open_web_text_dataset_dict()
#       1 def build_open_web_text_dataset_dict():
#       2     train_shards = [base_file_path + str(i) + ".txt" for i in range(84)]
#       3     return DatasetDict({
# ----> 4         "train": Dataset.from_generator(open_web_text_dataset_gen, gen_kwargs={"shards": train_shards, "dataset_name": "train"})
#       5     })
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\arrow_dataset.py:1125, in Dataset.from_generator(generator, features, cache_dir, keep_in_memory, gen_kwargs, num_proc, **kwargs)
#    1068 """Create a Dataset from a generator.
#    1069
#    1070 Args:
#    (...)
#    1113 ```
#    1114 """
#    1115 from .io.generator import GeneratorDatasetInputStream
#    1117 return GeneratorDatasetInputStream(
#    1118     generator=generator,
#    1119     features=features,
#    1120     cache_dir=cache_dir,
#    1121     keep_in_memory=keep_in_memory,
#    1122     gen_kwargs=gen_kwargs,
#    1123     num_proc=num_proc,
#    1124     **kwargs,
# -> 1125 ).read()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\io\generator.py:47, in GeneratorDatasetInputStream.read(self)
#      44     verification_mode = None
#      45     base_path = None
# ---> 47     self.builder.download_and_prepare(
#      48         download_config=download_config,
#      49         download_mode=download_mode,
#      50         verification_mode=verification_mode,
#      51         base_path=base_path,
#      52         num_proc=self.num_proc,
#      53     )
#      54     dataset = self.builder.as_dataset(
#      55         split="train", verification_mode=verification_mode, in_memory=self.keep_in_memory
#      56     )
#      57 return dataset
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\builder.py:1027, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#    1025     if num_proc is not None:
#    1026         prepare_split_kwargs["num_proc"] = num_proc
# -> 1027     self._download_and_prepare(
#    1028         dl_manager=dl_manager,
#    1029         verification_mode=verification_mode,
#    1030         **prepare_split_kwargs,
#    1031         **download_and_prepare_kwargs,
#    1032     )
#    1033 # Sync info
#    1034 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\builder.py:1789, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs)
#    1788 def _download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs):
# -> 1789     super()._download_and_prepare(
#    1790         dl_manager,
#    1791         verification_mode,
#    1792         check_duplicate_keys=verification_mode == VerificationMode.BASIC_CHECKS
#    1793         or verification_mode == VerificationMode.ALL_CHECKS,
#    1794         **prepare_splits_kwargs,
#    1795     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\builder.py:1122, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#    1118 split_dict.add(split_generator.split_info)
#    1120 try:
#    1121     # Prepare split will record examples associated to the split
# -> 1122     self._prepare_split(split_generator, **prepare_split_kwargs)
#    1123 except OSError as e:
#    1124     raise OSError(
#    1125         "Cannot find data file. "
#    1126         + (self.manual_download_instructions or "")
#    1127         + "\nOriginal error:\n"
#    1128         + str(e)
#    1129     ) from None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\builder.py:1627, in GeneratorBasedBuilder._prepare_split(self, split_generator, check_duplicate_keys, file_format, num_proc, max_shard_size)
#    1625 job_id = 0
#    1626 with pbar:
# -> 1627     for job_id, done, content in self._prepare_split_single(
#    1628         gen_kwargs=gen_kwargs, job_id=job_id, **_prepare_split_args
#    1629     ):
#    1630         if done:
#    1631             result = content
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\builder.py:1748, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1746 try:
#    1747     _time = time.time()
# -> 1748     for key, record in generator:
#    1749         if max_shard_size is not None and writer._num_bytes > max_shard_size:
#    1750             num_examples, num_bytes = writer.finalize()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\packaged_modules\generator\generator.py:30, in Generator._generate_examples(self, **gen_kwargs)
#      29 def _generate_examples(self, **gen_kwargs):
# ---> 30     for idx, ex in enumerate(self.config.generator(**gen_kwargs)):
#      31         yield idx, ex
#
# Cell In[4], line 7, in open_web_text_dataset_gen(shards, dataset_name)
#       5 with open(shard, "r", encoding="utf-8") as file:
#       6     for text in file:
# ----> 7         yield {"idx": idx, "text": tokenizer(text[0:-1], max_length = 512, truncation = True)['input_ids'][1:-1]}
#       8         idx += 1
#       9     progress_bar.update()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_base.py:2872, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2870     if not self._in_target_context_manager:
#    2871         self._switch_to_input_mode()
# -> 2872     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2873 if text_target is not None:
#    2874     self._switch_to_target_mode()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_base.py:2978, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2958     return self.batch_encode_plus(
#    2959         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2960         add_special_tokens=add_special_tokens,
#    (...)
#    2975         **kwargs,
#    2976     )
#    2977 else:
# -> 2978     return self.encode_plus(
#    2979         text=text,
#    2980         text_pair=text_pair,
#    2981         add_special_tokens=add_special_tokens,
#    2982         padding=padding,
#    2983         truncation=truncation,
#    2984         max_length=max_length,
#    2985         stride=stride,
#    2986         is_split_into_words=is_split_into_words,
#    2987         pad_to_multiple_of=pad_to_multiple_of,
#    2988         return_tensors=return_tensors,
#    2989         return_token_type_ids=return_token_type_ids,
#    2990         return_attention_mask=return_attention_mask,
#    2991         return_overflowing_tokens=return_overflowing_tokens,
#    2992         return_special_tokens_mask=return_special_tokens_mask,
#    2993         return_offsets_mapping=return_offsets_mapping,
#    2994         return_length=return_length,
#    2995         verbose=verbose,
#    2996         **kwargs,
#    2997     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_base.py:3051, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3041 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3042 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3043     padding=padding,
#    3044     truncation=truncation,
#    (...)
#    3048     **kwargs,
#    3049 )
# -> 3051 return self._encode_plus(
#    3052     text=text,
#    3053     text_pair=text_pair,
#    3054     add_special_tokens=add_special_tokens,
#    3055     padding_strategy=padding_strategy,
#    3056     truncation_strategy=truncation_strategy,
#    3057     max_length=max_length,
#    3058     stride=stride,
#    3059     is_split_into_words=is_split_into_words,
#    3060     pad_to_multiple_of=pad_to_multiple_of,
#    3061     return_tensors=return_tensors,
#    3062     return_token_type_ids=return_token_type_ids,
#    3063     return_attention_mask=return_attention_mask,
#    3064     return_overflowing_tokens=return_overflowing_tokens,
#    3065     return_special_tokens_mask=return_special_tokens_mask,
#    3066     return_offsets_mapping=return_offsets_mapping,
#    3067     return_length=return_length,
#    3068     verbose=verbose,
#    3069     **kwargs,
#    3070 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_fast.py:576, in PreTrainedTokenizerFast._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     554 def _encode_plus(
#     555     self,
#     556     text: Union[TextInput, PreTokenizedInput],
#    (...)
#     573     **kwargs,
#     574 ) -> BatchEncoding:
#     575     batched_input = [(text, text_pair)] if text_pair else [text]
# --> 576     batched_output = self._batch_encode_plus(
#     577         batched_input,
#     578         is_split_into_words=is_split_into_words,
#     579         add_special_tokens=add_special_tokens,
#     580         padding_strategy=padding_strategy,
#     581         truncation_strategy=truncation_strategy,
#     582         max_length=max_length,
#     583         stride=stride,
#     584         pad_to_multiple_of=pad_to_multiple_of,
#     585         return_tensors=return_tensors,
#     586         return_token_type_ids=return_token_type_ids,
#     587         return_attention_mask=return_attention_mask,
#     588         return_overflowing_tokens=return_overflowing_tokens,
#     589         return_special_tokens_mask=return_special_tokens_mask,
#     590         return_offsets_mapping=return_offsets_mapping,
#     591         return_length=return_length,
#     592         verbose=verbose,
#     593         **kwargs,
#     594     )
#     596     # Return tensor is None, then we can remove the leading batch axis
#     597     # Overflowing tokens are returned as a batch of output so we keep them in this case
#     598     if return_tensors is None and not return_overflowing_tokens:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_fast.py:504, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose)
#     495 # Set the truncation and padding strategy and restore the initial configuration
#     496 self.set_truncation_and_padding(
#     497     padding_strategy=padding_strategy,
#     498     truncation_strategy=truncation_strategy,
#    (...)
#     501     pad_to_multiple_of=pad_to_multiple_of,
#     502 )
# --> 504 encodings = self._tokenizer.encode_batch(
#     505     batch_text_or_text_pairs,
#     506     add_special_tokens=add_special_tokens,
#     507     is_pretokenized=is_split_into_words,
#     508 )
#     510 # Convert encoding to dict
#     511 # `Tokens` has type: Tuple[
#     512 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     513 #                       List[EncodingFast]
#     514 #                    ]
#     515 # with nested dimensions corresponding to batch, overflows, sequence length
#     516 tokens_and_encodings = [
#     517     self._convert_encoding(
#     518         encoding=encoding,
#    (...)
#     527     for encoding in encodings
#     528 ]
#
# KeyboardInterrupt:

# %%
print(open_web_text_dataset_dict)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['idx', 'text'],
#         num_rows: 2769
#     })
# })

# %%
open_web_text_dataset_dict.save_to_disk(dataset_folder_path)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/2769 [00:00<?, ? examples/s]
